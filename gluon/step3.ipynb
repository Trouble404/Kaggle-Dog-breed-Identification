# %% [markdown]
# # Step 3: Train model with Ensemble Features

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import mxnet as mx
from mxnet import gluon
from mxnet import ndarray as nd
from mxnet import autograd
from mxnet.gluon import nn

import h5py
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

# %%
ctx = mx.gpu() # GPU WORKING HERE

# %% [markdown]
# ![image](https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/argmax.PNG)
# ![image](https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/entropy_softmax.PNG)

# %%
 # calculate the acc of model
def accuracy(output, labels):
    return nd.mean(nd.argmax(output, axis=1) == labels).asscalar() 
    # assclar() -> transofrm arrary to coresspoding scalar
    # argmax() -> find the maxmum value in muti dimentional arrary

# calculate the loss and acc of model
def evaluate(net, data_iter):
    loss, acc, n = 0., 0., 0.
    steps = len(data_iter) # iteration
    for data, label in data_iter:
        data, label = data.as_in_context(ctx), label.as_in_context(ctx)
        output = net(data)
        acc += accuracy(output, label)
        loss += nd.mean(softmax_cross_entropy(output, label)).asscalar() # Calculate cross entropy of softmax output and one-hot label.
    return loss/steps, acc/steps # return average loss and acc

# %% [markdown]
# # Load features vector in step 2

# %%
with h5py.File('features_train.h5', 'r') as f:
    #features_vgg = np.array(f['vgg'])
    features_resnet = np.array(f['resnet'])
    features_densenet = np.array(f['densenet'])
    features_inception = np.array(f['inception'])
    labels = np.array(f['labels']) # label of different dogs

# %%
from IPython.core.interactiveshell import InteractiveShell 
InteractiveShell.ast_node_interactivity = "all" # display muti result in jupyter

# %% [markdown]
# **Shape of features vector**
#
# **Vgg is a old model, therefore using other 3 models to train new model here**

# %%
#features_vgg.shape
labels.shape
features_resnet.shape
features_densenet.shape
features_inception.shape
# Out:
# (10222L,)
# (10222L, 2048L)
# (10222L, 2208L)
# (10222L, 2048L)

# %% [markdown]
# **Image-> Features of densenet, resnet and inception. And then Merge to obtain a new feature vector**

# %%
# Extract first two cloums as features
features_resnet = features_resnet.reshape(features_resnet.shape[:2])
features_inception = features_inception.reshape(features_inception.shape[:2])
# Merge 3 features
features = np.concatenate([features_resnet, features_densenet, features_inception], axis=-1)

# %%
features_densenet.shape
features_resnet.shape
features_inception.shape
features.shape
# Out:
# (10222L, 2208L)
# (10222L, 2048L)
# (10222L, 2048L)
# (10222L, 6304L)

# %% [markdown]
# ## Constrct iterator by ArrayDataset and DataLoader

# %%
X_train, X_val, y_train, y_val = train_test_split(features, labels, test_size=0.2) # use 20% data for validation data

#constrct dataset
dataset_train = gluon.data.ArrayDataset(nd.array(X_train), nd.array(y_train))
dataset_val = gluon.data.ArrayDataset(nd.array(X_val), nd.array(y_val))

batch_size = 128 # Size of mini-batch
data_iter_train = gluon.data.DataLoader(dataset_train, batch_size, shuffle=True) # shuffle sort of dataset
data_iter_val = gluon.data.DataLoader(dataset_val, batch_size)

# %% [markdown]
# ## Constrct Model
# ![image](https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/softmax_loss.PNG)
#
# **And we need set optimize and learning rate in [gluon.Trainer](https://zh.gluon.ai/chapter_optimization/adam-gluon.html)**

# %%
net = nn.Sequential() # define a Sequential network
with net.name_scope():
    net.add(nn.Dense(256, activation='relu'))
    net.add(nn.Dropout(0.5)) # prevent overfitting
    net.add(nn.Dense(120)) # 120 breeds dogs classification

net.initialize(ctx=ctx)
softmax_cross_entropy = gluon.loss.SoftmaxCrossEntropyLoss()
trainer = gluon.Trainer(net.collect_params(), 'adam', {'learning_rate': 1e-4, 'wd': 1e-5})
net
# Out:
# Sequential(
#   (0): Dense(None -> 256, Activation(relu))
#   (1): Dropout(p = 0.5)
#   (2): Dense(None -> 120, linear)
# )

# %% [markdown]
# ## Train Model
# ![image](https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/record.PNG)

# %%
for epoch in range(50): # iterat 50 times
    # initialize parameters
    train_loss = 0.
    train_acc = 0.
    steps = len(data_iter_train)
    for data, label in data_iter_train: # shuffled train data with batch size 128
        data, label = data.as_in_context(ctx), label.as_in_context(ctx)
        
        with autograd.record(): # auto derivation of loss
            output = net(data)
            loss = softmax_cross_entropy(output, label)
        
        loss.backward() # derivation
        trainer.step(batch_size) 
        # 因为loss.backward()求出的梯度是一个batch的梯度之和，所以需要除以batch_size得到平均梯度，就在trainer.step(batch_size)中这样表示
        
        train_loss += nd.mean(loss).asscalar()
        train_acc += accuracy(output, label)
    
    val_loss, val_acc = evaluate(net, data_iter_val)
    print("Epoch %d. loss: %.4f, acc: %.2f%%, val_loss %.4f, val_acc %.2f%%" % (
        epoch+1, train_loss/steps, train_acc/steps*100, val_loss, val_acc*100))
# Out:
# Epoch 1. loss: 4.5870, acc: 5.29%, val_loss 3.8906, val_acc 28.16%
# Epoch 2. loss: 3.4818, acc: 24.70%, val_loss 2.5015, val_acc 63.03%
# Epoch 3. loss: 2.3550, acc: 47.39%, val_loss 1.4636, val_acc 78.58%
# Epoch 4. loss: 1.6194, acc: 62.59%, val_loss 0.9511, val_acc 84.06%
# Epoch 5. loss: 1.2121, acc: 70.86%, val_loss 0.7209, val_acc 85.97%
# Epoch 6. loss: 0.9733, acc: 75.26%, val_loss 0.5839, val_acc 87.73%
# Epoch 7. loss: 0.8166, acc: 78.99%, val_loss 0.5180, val_acc 87.82%
# Epoch 8. loss: 0.7202, acc: 80.89%, val_loss 0.4620, val_acc 89.68%
# Epoch 9. loss: 0.6612, acc: 81.90%, val_loss 0.4350, val_acc 89.24%
# Epoch 10. loss: 0.5952, acc: 83.82%, val_loss 0.4122, val_acc 89.59%
# Epoch 11. loss: 0.5422, acc: 84.93%, val_loss 0.3886, val_acc 89.49%
# Epoch 12. loss: 0.5066, acc: 85.46%, val_loss 0.3788, val_acc 89.34%
# Epoch 13. loss: 0.4878, acc: 86.22%, val_loss 0.3684, val_acc 89.54%
# Epoch 14. loss: 0.4365, acc: 87.81%, val_loss 0.3545, val_acc 89.68%
# Epoch 15. loss: 0.4178, acc: 87.97%, val_loss 0.3477, val_acc 90.07%
# Epoch 16. loss: 0.4081, acc: 88.03%, val_loss 0.3414, val_acc 89.78%
# Epoch 17. loss: 0.3789, acc: 89.11%, val_loss 0.3350, val_acc 90.17%
# Epoch 18. loss: 0.3541, acc: 89.75%, val_loss 0.3289, val_acc 89.98%
# Epoch 19. loss: 0.3434, acc: 90.01%, val_loss 0.3273, val_acc 90.32%
# Epoch 20. loss: 0.3352, acc: 90.22%, val_loss 0.3199, val_acc 90.61%
# Epoch 21. loss: 0.3176, acc: 90.87%, val_loss 0.3190, val_acc 90.12%
# Epoch 22. loss: 0.3043, acc: 91.16%, val_loss 0.3148, val_acc 90.27%
# Epoch 23. loss: 0.2958, acc: 91.79%, val_loss 0.3149, val_acc 90.56%
# Epoch 24. loss: 0.2902, acc: 91.25%, val_loss 0.3097, val_acc 90.52%
# Epoch 25. loss: 0.2652, acc: 92.02%, val_loss 0.3068, val_acc 90.47%
# Epoch 26. loss: 0.2689, acc: 92.00%, val_loss 0.3071, val_acc 90.52%
# Epoch 27. loss: 0.2451, acc: 93.10%, val_loss 0.3033, val_acc 90.51%
# Epoch 28. loss: 0.2461, acc: 92.80%, val_loss 0.2988, val_acc 90.71%
# Epoch 29. loss: 0.2392, acc: 92.94%, val_loss 0.3045, val_acc 90.37%
# Epoch 30. loss: 0.2236, acc: 93.46%, val_loss 0.3090, val_acc 90.47%
# Epoch 31. loss: 0.2210, acc: 93.60%, val_loss 0.3016, val_acc 90.66%
# Epoch 32. loss: 0.2097, acc: 93.97%, val_loss 0.3028, val_acc 90.27%
# Epoch 33. loss: 0.2058, acc: 94.04%, val_loss 0.2996, val_acc 90.56%
# Epoch 34. loss: 0.1992, acc: 94.28%, val_loss 0.3000, val_acc 90.86%
# Epoch 35. loss: 0.1821, acc: 94.69%, val_loss 0.2989, val_acc 90.57%
# Epoch 36. loss: 0.1861, acc: 94.68%, val_loss 0.2942, val_acc 91.10%
# Epoch 37. loss: 0.1888, acc: 94.43%, val_loss 0.3011, val_acc 90.81%
# Epoch 38. loss: 0.1762, acc: 95.00%, val_loss 0.2986, val_acc 90.61%
# Epoch 39. loss: 0.1690, acc: 95.38%, val_loss 0.2957, val_acc 90.66%
# Epoch 40. loss: 0.1631, acc: 95.24%, val_loss 0.2914, val_acc 90.61%
# Epoch 41. loss: 0.1596, acc: 95.55%, val_loss 0.2951, val_acc 91.00%
# Epoch 42. loss: 0.1495, acc: 95.72%, val_loss 0.2962, val_acc 91.00%
# Epoch 43. loss: 0.1470, acc: 95.90%, val_loss 0.2951, val_acc 90.56%
# Epoch 44. loss: 0.1412, acc: 96.25%, val_loss 0.2970, val_acc 90.81%
# Epoch 45. loss: 0.1422, acc: 96.06%, val_loss 0.3002, val_acc 91.10%
# Epoch 46. loss: 0.1351, acc: 96.04%, val_loss 0.2936, val_acc 90.76%
# Epoch 47. loss: 0.1343, acc: 96.19%, val_loss 0.2977, val_acc 90.90%
# Epoch 48. loss: 0.1328, acc: 96.36%, val_loss 0.2987, val_acc 91.20%
# Epoch 49. loss: 0.1258, acc: 96.44%, val_loss 0.2953, val_acc 91.25%
# Epoch 50. loss: 0.1210, acc: 96.89%, val_loss 0.2984, val_acc 91.25%

# %% [markdown]
# # Load feature vector of test data

# %%
with h5py.File('features_test.h5', 'r') as f:
    #features_vgg_test = np.array(f['vgg'])
    features_resnet_test = np.array(f['resnet'])
    features_densenet_test = np.array(f['densenet'])
    features_inception_test = np.array(f['inception'])

# %% [markdown]
# **Features mergy same as training part**

# %%
features_resnet_test = features_resnet_test.reshape(features_resnet_test.shape[:2])
features_inception_test = features_inception_test.reshape(features_inception_test.shape[:2])

features_test = np.concatenate([features_resnet_test, features_densenet_test, features_inception_test], axis=-1)

# %% [markdown]
# ## Prediction

# %%
# %%time
output = nd.softmax(net(nd.array(features_test).as_in_context(ctx))).asnumpy()
# Out:
# Wall time: 1.02 s

# %%
output.shape
# Out:
# (10357L, 120L)

# %% [markdown]
# **integration to submission format**

# %%
# %%time
df = pd.read_csv('sample_submission.csv')

for i, c in enumerate(df.columns[1:]):
    df[c] = output[:,i]
    
#df.to_csv('pred.csv', index=None)
# Out:
# Wall time: 733 ms

# %%
df
# Out:
#                                      id  affenpinscher  afghan_hound  \
# 0      000621fb3cbb32d8935728e48679680e   3.338809e-08  1.363769e-07
# 1      00102ee9d8eb90812350685311fe5890   7.239021e-08  1.030238e-08
# 2      0012a730dfa437f5f3613fb75efcd4ce   1.761396e-09  2.193402e-04
# 3      001510bc8570bbeee98c8d80c8a95ec1   2.408999e-04  3.334786e-07
# 4      001a5f3114548acdefa3d4da05474c2e   5.872858e-02  1.650531e-05
# 5      00225dcd3e4d2410dd53239f95c0352f   5.303541e-06  4.330623e-03
# 6      002c2a3117c2193b4d26400ce431eebd   3.927715e-07  1.799073e-07
# 7      002c58d413a521ae8d1a5daeb35fc803   1.560831e-06  3.612611e-07
# 8      002f80396f1e3db687c5932d7978b196   3.354319e-08  2.925018e-07
# 9      0036c6bcec6031be9e62a257b1c3c442   4.857402e-10  6.359738e-08
# 10     0041940322116ae58c38130f5a6f71f9   8.085355e-07  5.915217e-07
# 11     0042d6bf3e5f3700865886db32689436   2.859133e-06  2.410148e-07
# 12     004476c96f575879af4af471af65cae8   3.465929e-08  3.228750e-08
# 13     00485d47de966a9437ad3b33ac193b6f   4.920213e-05  1.652063e-05
# 14     00496f65de6cc319145ce97bd6e90360   2.581579e-09  3.819398e-06
# 15     004bf14426d1a830d459a9e0c0721309   4.223531e-07  3.464178e-06
# 16     004c3721eb88358f462cdcec6b2380b7   1.172232e-06  2.653029e-07
# 17     00559f56aab7e0a7749220f6aed65162   4.891419e-05  3.688400e-05
# 18     005b281f1a4d6f29d527c9585e9bd33c   8.368997e-06  7.047171e-08
# 19     005b6c6c76fefd6b458ef6fb6e54da6e   4.531930e-10  1.335003e-04
# 20     006870b49353779b25eeb91fed43c31a   1.187767e-03  3.420939e-05
# 21     0068f3a21b159ece126a28580cdad7a0   3.289428e-07  1.202604e-06
# 22     0069b1cc4546fc98f84f981bf9a0696a   1.296721e-07  1.735042e-10
# 23     0077bc3c63486ff09d3774d956af8f76   9.176526e-08  1.016972e-06
# 24     00780e5d2bf4f7e4b5f96d08ddde669a   1.562272e-07  2.279579e-05
# 25     007ed71136966728f5c0936e23c8286b   5.915777e-08  4.115961e-07
# 26     0081831ceb49cd64212c32b884036b82   5.401730e-10  4.510649e-07
# 27     00846c0edd5aa4f10ee5e9b84d7310a6   3.635542e-07  7.544951e-06
# 28     0092bd9e90a13403373fc0e9e1218938   2.485643e-09  2.534479e-06
# 29     009a3c4f6626e4750f74ceb8e8ed8760   7.337597e-07  1.097292e-06
# ...                                 ...            ...           ...
# 10327  ff7e00f66ebf0042c5ccb74170eecb1a   7.398182e-07  3.799144e-06
# 10328  ff8c3ee47324ecf110e147f29747952a   4.322288e-07  1.126986e-06
# 10329  ff8f9a768544fda79ffad62576f4d129   8.037298e-07  4.745812e-05
# 10330  ff8ff2e36aa2a20d5d8585e2f686dbda   3.129536e-06  1.979228e-06
# 10331  ff9742bc22b5830176e85490cf54cdf7   1.976799e-06  1.074005e-06
# 10332  ff9b317696e29ca8cd27da30a896edcd   9.611443e-07  5.184176e-07
# 10333  ffa316c6db0919d6bad1a5ed483e6722   3.771000e-09  3.203589e-10
# 10334  ffa76e07dc686174c2a55fdbdca68bb3   6.286600e-09  3.305869e-07
# 10335  ffadae851b94ece57602da7edf72d689   4.830407e-09  9.364376e-09
# 10336  ffb3a78e4a162c173219194687eb6054   3.641619e-06  9.265864e-06
# 10337  ffb55dbaa32939c109ef42df0668e077   1.249867e-10  4.521611e-09
# 10338  ffb68ded4a2247b3c011840ece0a605c   1.681756e-06  7.505609e-07
# 10339  ffb8bceeac5b3f587f67391ad346d454   6.324501e-06  1.616254e-07
# 10340  ffbb6663b38e903dbd1efa5dce2d0bbb   1.491918e-06  2.513393e-06
# 10341  ffbcda9eb84339cc5be15fd9900596a2   2.969615e-07  4.433197e-06
# 10342  ffbcf032231bb0b025f9070d42ab7e8f   7.440343e-09  1.521065e-06
# 10343  ffc0233904f4d03afe1484be791e09d6   1.498213e-07  2.085052e-08
# 10344  ffd06687c72445b0c6e8a130a0a8711a   1.012017e-05  9.225028e-04
# 10345  ffd304c521f43819f3824177fd9efeb0   4.596905e-06  9.412197e-07
# 10346  ffd3ce0566df4be8049c767a329faaf7   4.998032e-05  2.905404e-07
# 10347  ffd87c3e44faa0e3ee5fbbdc4c63b59b   3.669754e-08  1.238055e-07
# 10348  ffe2315cf566e039516f5a4a5e52ff1b   1.381749e-05  1.030055e-06
# 10349  ffe42f4b4c50d4f18c2b34500f391152   2.148468e-08  3.634550e-06
# 10350  ffe563b1b8c0dcd0797c4362c6754b96   5.692571e-05  6.942870e-03
# 10351  ffe9717b7937c262f849416976f7620a   2.606416e-05  1.690743e-05
# 10352  ffeda8623d4eee33c6d1156a2ecbfcf8   3.670300e-08  4.509324e-05
# 10353  fff1ec9e6e413275984966f745a313b0   3.606830e-09  3.437467e-09
# 10354  fff74b59b758bbbf13a5793182a9bbe4   4.672796e-07  5.772968e-07
# 10355  fff7d50d848e8014ac1e9172dc6762a3   1.846590e-05  1.453134e-07
# 10356  fffbff22c1f51e3dc80c4bf04089545b   2.043253e-07  8.845341e-05
#
#        african_hunting_dog      airedale  american_staffordshire_terrier  \
# 0             4.968185e-08  1.148647e-08                    2.780667e-10
# 1             6.921762e-09  5.885484e-08                    2.247034e-08
# 2             4.916691e-07  2.203355e-08                    2.959070e-09
# 3             2.043313e-07  1.719671e-07                    4.063948e-06
# 4             4.963626e-07  4.443505e-07                    5.373401e-07
# 5             3.825677e-06  7.040541e-04                    3.575608e-05
# 6             2.242376e-08  3.807708e-07                    4.901096e-08
# 7             8.677345e-08  7.700099e-07                    5.193937e-07
# 8             2.639096e-06  1.646592e-06                    1.238219e-07
# 9             3.664490e-07  3.467145e-09                    4.758820e-07
# 10            9.737628e-09  1.497514e-08                    8.759224e-08
# 11            3.529095e-07  6.395342e-06                    5.323119e-05
# 12            6.702335e-09  1.636881e-08                    7.244674e-08
# 13            1.569126e-03  1.206200e-03                    1.000916e-05
# 14            2.557043e-07  5.502374e-07                    1.140290e-06
# 15            1.221510e-06  8.106652e-08                    2.759406e-07
# 16            4.801709e-05  7.819815e-06                    3.719448e-06
# 17            3.987219e-06  1.290641e-04                    8.696347e-05
# 18            9.432969e-07  3.312664e-04                    1.076761e-06
# 19            1.343519e-08  1.997206e-08                    1.862537e-09
# 20            3.256408e-05  5.461157e-07                    6.038343e-05
# 21            2.866665e-06  1.478604e-07                    4.673412e-06
# 22            5.698948e-07  1.792176e-07                    2.630660e-07
# 23            6.032802e-07  7.487051e-07                    2.226359e-03
# 24            7.817692e-08  2.965761e-07                    8.987730e-09
# 25            1.466891e-08  3.292713e-09                    7.298431e-09
# 26            1.792439e-08  9.907338e-07                    1.697695e-07
# 27            7.852944e-06  2.840737e-06                    1.097274e-04
# 28            7.554393e-08  4.212898e-08                    8.854327e-09
# 29            1.107218e-06  7.001015e-01                    9.428833e-05
# ...                    ...           ...                             ...
# 10327         2.326671e-07  1.281966e-06                    7.033865e-08
# 10328         2.845375e-08  5.603587e-07                    1.978474e-07
# 10329         4.092051e-05  1.133255e-06                    7.018266e-05
# 10330         7.444563e-07  8.195945e-06                    1.243253e-03
# 10331         4.313814e-07  4.028725e-07                    4.625615e-07
# 10332         4.459603e-07  1.025304e-06                    1.076159e-06
# 10333         2.317951e-10  3.118028e-08                    3.208128e-07
# 10334         5.001927e-07  1.184359e-07                    2.575577e-07
# 10335         2.247796e-09  5.254812e-09                    2.035479e-02
# 10336         3.522847e-06  8.435106e-01                    1.483426e-05
# 10337         3.936174e-10  5.241525e-08                    2.534194e-09
# 10338         6.989087e-08  3.413131e-06                    4.308512e-06
# 10339         7.901937e-06  9.704336e-07                    6.240653e-06
# 10340         2.073842e-07  9.186087e-07                    5.582939e-06
# 10341         2.048325e-06  2.525186e-07                    2.419436e-04
# 10342         3.931456e-07  2.317805e-07                    1.563238e-07
# 10343         9.684791e-08  5.584903e-04                    1.121156e-05
# 10344         3.764360e-06  3.687951e-06                    9.041658e-05
# 10345         5.383125e-07  1.046514e-07                    1.154434e-04
# 10346         5.605970e-07  2.461263e-07                    2.478721e-08
# 10347         3.073519e-05  4.470408e-08                    1.446470e-08
# 10348         1.666466e-06  6.029975e-06                    9.901991e-06
# 10349         8.392208e-07  3.229245e-08                    3.050113e-08
# 10350         2.101757e-05  3.201519e-02                    4.852438e-05
# 10351         2.354382e-04  3.080623e-04                    1.203794e-05
# 10352         1.024453e-06  5.421420e-06                    4.995294e-06
# 10353         6.812053e-09  2.665362e-06                    3.180937e-05
# 10354         1.542689e-04  1.466542e-07                    1.240180e-08
# 10355         7.237973e-09  6.232097e-08                    2.813611e-08
# 10356         1.120230e-04  7.500743e-08                    1.410618e-07
#
#         appenzeller  australian_terrier       basenji        basset  \
# 0      5.390003e-08        9.177727e-08  6.770148e-08  1.868445e-08
# 1      5.021575e-08        8.854153e-08  8.726333e-09  2.504320e-08
# 2      1.149469e-08        2.526606e-08  7.704136e-09  2.198103e-07
# 3      9.020300e-07        8.348402e-07  1.580270e-06  1.995657e-06
# 4      7.837461e-06        1.826465e-04  4.362540e-05  2.521674e-06
# 5      1.184968e-05        2.657193e-05  8.425179e-05  4.762358e-05
# 6      3.611114e-08        9.996958e-01  8.003313e-08  1.412641e-09
# 7      4.404285e-07        1.776615e-06  1.675802e-07  1.238933e-06
# 8      9.054934e-08        4.328432e-08  3.917257e-10  4.610802e-08
# 9      4.969432e-09        7.052568e-08  2.922750e-09  3.934375e-07
# 10     2.179143e-07        1.411162e-06  2.182831e-07  6.126502e-09
# 11     1.861471e-06        2.692496e-05  6.195539e-07  4.856308e-06
# 12     4.573096e-10        4.847072e-09  5.193262e-09  7.850325e-09
# 13     6.167500e-05        6.740337e-02  2.208019e-03  2.179848e-06
# 14     6.848232e-07        2.240179e-06  2.597673e-06  2.344264e-05
# 15     7.152927e-08        9.924297e-08  2.668970e-08  2.246717e-07
# 16     1.685424e-06        9.259852e-06  2.284660e-05  7.544735e-07
# 17     1.243597e-05        4.597398e-05  4.667578e-06  8.544076e-06
# 18     9.507867e-07        1.196729e-03  1.947920e-07  2.116218e-07
# 19     4.299131e-09        5.090798e-09  3.247644e-09  3.448092e-08
# 20     8.933069e-05        9.525724e-03  5.871644e-05  9.738761e-06
# 21     1.530088e-05        6.892480e-07  3.630909e-06  4.743585e-07
# 22     9.986690e-08        8.452797e-07  1.091970e-07  5.679040e-10
# 23     1.285725e-05        1.764311e-06  1.011466e-06  7.243424e-06
# 24     3.904239e-08        4.433081e-05  2.982938e-08  5.547411e-08
# 25     3.512769e-08        4.230175e-08  8.730132e-09  1.709801e-08
# 26     3.178394e-08        3.379439e-08  8.076745e-09  1.012965e-05
# 27     1.012647e-06        1.653950e-06  2.457080e-07  6.839745e-07
# 28     5.119626e-08        4.328835e-08  1.561047e-08  6.710007e-07
# 29     6.217835e-06        2.826215e-05  1.744536e-06  7.350219e-06
# ...             ...                 ...           ...           ...
# 10327  1.340337e-05        1.848262e-06  2.118188e-07  9.436243e-08
# 10328  4.058225e-08        1.154151e-06  3.596609e-07  1.106117e-07
# 10329  1.787095e-04        8.505509e-05  1.453357e-02  8.454342e-05
# 10330  1.024918e-05        6.146355e-05  4.900734e-03  9.785656e-06
# 10331  7.642570e-07        1.739198e-03  1.140232e-06  1.163701e-07
# 10332  1.303869e-03        4.652868e-06  2.108733e-05  2.503145e-07
# 10333  5.957899e-08        9.227634e-10  1.095026e-09  5.886339e-09
# 10334  7.961178e-07        1.158952e-07  1.920306e-07  4.661745e-06
# 10335  3.634771e-08        9.731820e-09  1.432728e-08  2.950570e-08
# 10336  1.860565e-06        2.035888e-04  3.040236e-07  1.929061e-06
# 10337  8.039861e-10        1.818124e-08  1.642018e-08  6.848618e-09
# 10338  3.784117e-06        3.053590e-06  6.276541e-06  2.405112e-06
# 10339  1.414969e-03        3.384104e-05  6.819666e-06  8.231455e-07
# 10340  2.735760e-05        1.486550e-03  3.719312e-07  3.285231e-07
# 10341  4.633488e-07        1.145812e-07  3.189323e-07  2.602530e-07
# 10342  2.193865e-06        3.130095e-07  4.891756e-08  4.534456e-06
# 10343  4.564041e-08        5.652399e-07  1.392558e-07  1.886072e-06
# 10344  2.889732e-03        3.734076e-04  5.723046e-05  3.241219e-05
# 10345  2.667005e-06        3.890962e-07  6.868464e-06  2.688305e-07
# 10346  3.876320e-07        2.902289e-05  1.127085e-07  1.925457e-07
# 10347  7.945939e-08        4.342032e-07  2.369226e-06  3.770932e-08
# 10348  1.501388e-06        6.099023e-06  4.784721e-07  4.450424e-07
# 10349  9.240924e-08        5.882003e-08  7.908682e-09  8.692681e-08
# 10350  2.633356e-04        9.374294e-03  1.952990e-05  1.379486e-05
# 10351  6.859101e-04        7.774677e-05  7.095869e-06  4.276958e-05
# 10352  2.512305e-07        4.772658e-07  3.746308e-06  4.767656e-06
# 10353  3.566156e-08        1.536157e-06  1.152848e-08  1.230069e-07
# 10354  1.117616e-07        1.473007e-05  6.946356e-07  8.740000e-08
# 10355  9.234536e-07        1.503638e-06  5.891981e-07  9.273392e-07
# 10356  6.919848e-07        4.659023e-08  2.770719e-08  5.326404e-08
#
#              ...            toy_poodle   toy_terrier        vizsla  \
# 0            ...          4.450668e-08  2.936551e-08  8.700171e-09
# 1            ...          1.415466e-07  1.383130e-08  4.042690e-08
# 2            ...          1.965128e-08  5.901514e-07  8.150218e-08
# 3            ...          2.180770e-06  7.387077e-08  1.329163e-05
# 4            ...          3.347674e-05  1.232059e-05  2.311019e-06
# 5            ...          3.521474e-02  9.517459e-06  6.694744e-06
# 6            ...          6.167809e-10  1.829100e-07  9.745698e-08
# 7            ...          2.621426e-06  1.216539e-07  2.505230e-07
# 8            ...          1.247321e-08  2.804119e-08  3.729168e-06
# 9            ...          2.548908e-07  4.233171e-09  3.136413e-06
# 10           ...          1.197331e-06  7.158549e-08  1.364666e-08
# 11           ...          3.725206e-06  3.021164e-06  2.613776e-06
# 12           ...          3.845907e-08  3.462352e-10  6.023570e-09
# 13           ...          6.523399e-05  8.549549e-04  8.921852e-05
# 14           ...          7.497848e-07  5.088707e-06  1.300448e-06
# 15           ...          1.058748e-07  1.921411e-09  1.230888e-07
# 16           ...          8.479296e-05  6.133270e-02  3.465305e-07
# 17           ...          3.730753e-05  1.925213e-05  1.067581e-05
# 18           ...          3.253643e-08  2.568908e-06  2.957207e-04
# 19           ...          3.449254e-08  7.382096e-09  5.971383e-09
# 20           ...          5.845507e-06  5.707510e-05  3.917162e-05
# 21           ...          1.613393e-07  4.363416e-07  1.331225e-06
# 22           ...          2.468391e-07  5.626211e-05  2.502201e-08
# 23           ...          2.025256e-05  5.437671e-05  2.306285e-05
# 24           ...          1.538976e-07  1.054350e-06  1.103057e-06
# 25           ...          1.556731e-09  2.866994e-09  4.164045e-09
# 26           ...          9.427060e-08  9.001380e-09  1.402073e-06
# 27           ...          3.477957e-07  1.902321e-06  7.813838e-06
# 28           ...          2.366087e-07  1.148434e-06  1.756741e-07
# 29           ...          1.568337e-06  1.103744e-04  1.341246e-04
# ...          ...                   ...           ...           ...
# 10327        ...          1.195312e-06  3.715358e-08  5.367881e-08
# 10328        ...          1.809815e-06  4.097327e-08  1.574795e-08
# 10329        ...          1.320091e-05  6.286730e-04  1.699180e-05
# 10330        ...          1.722816e-05  1.187376e-04  1.055026e-04
# 10331        ...          6.108183e-07  1.178647e-05  1.122744e-07
# 10332        ...          1.600300e-07  4.533561e-06  8.143429e-08
# 10333        ...          4.625482e-08  8.123534e-09  5.312479e-10
# 10334        ...          3.245570e-08  1.018671e-07  2.559071e-07
# 10335        ...          1.075854e-07  2.935411e-07  2.459529e-08
# 10336        ...          4.610806e-07  6.960811e-06  8.762073e-05
# 10337        ...          1.502679e-10  1.040006e-07  2.640611e-08
# 10338        ...          3.661292e-01  4.712802e-05  9.982172e-07
# 10339        ...          1.443909e-07  7.694999e-05  7.229813e-07
# 10340        ...          1.232920e-04  1.332758e-05  9.523832e-07
# 10341        ...          2.296326e-06  2.635145e-07  1.588322e-07
# 10342        ...          7.066911e-08  5.904355e-08  1.179379e-07
# 10343        ...          6.010720e-06  9.320071e-06  1.179972e-07
# 10344        ...          1.205324e-02  9.267955e-05  9.037136e-06
# 10345        ...          1.136890e-06  5.047222e-07  7.613050e-07
# 10346        ...          7.122195e-08  7.734592e-07  7.517635e-07
# 10347        ...          1.506340e-08  1.101309e-08  2.470375e-07
# 10348        ...          7.883845e-07  7.361830e-06  7.119510e-07
# 10349        ...          1.893415e-08  7.755450e-10  8.798708e-09
# 10350        ...          4.794447e-05  1.555940e-05  6.828315e-04
# 10351        ...          3.221606e-05  2.589635e-05  1.710925e-05
# 10352        ...          7.085022e-05  4.806389e-06  4.493622e-07
# 10353        ...          3.507735e-08  2.125085e-07  1.117617e-04
# 10354        ...          1.850990e-07  2.045659e-07  1.156019e-06
# 10355        ...          3.845805e-06  2.569862e-07  3.858369e-08
# 10356        ...          8.172008e-08  1.878349e-07  5.510315e-07
#
#        walker_hound    weimaraner  welsh_springer_spaniel  \
# 0      2.749717e-07  2.467090e-09            8.945009e-08
# 1      6.139040e-07  6.584788e-08            9.285507e-08
# 2      1.232072e-06  8.416451e-08            4.186788e-05
# 3      3.773214e-06  4.217096e-08            1.720226e-07
# 4      1.160790e-05  2.713161e-07            4.173835e-06
# 5      3.752566e-05  7.517276e-06            4.661342e-06
# 6      1.082523e-07  1.830247e-09            3.516850e-08
# 7      3.047260e-06  1.034301e-06            5.608574e-06
# 8      2.884877e-07  2.181859e-06            8.379592e-08
# 9      7.126030e-08  2.053677e-06            2.363686e-07
# 10     3.794955e-08  6.397137e-08            5.239468e-09
# 11     1.538119e-06  4.002067e-05            8.109128e-06
# 12     1.459943e-08  1.322038e-08            2.931145e-08
# 13     2.962932e-05  4.607974e-08            1.123777e-04
# 14     4.999551e-03  1.077352e-06            7.971556e-08
# 15     3.691168e-07  9.475575e-09            2.987225e-07
# 16     2.890549e-06  5.290460e-07            1.633068e-05
# 17     3.127768e-05  3.381873e-05            6.803216e-06
# 18     6.366568e-06  1.322240e-07            6.941856e-07
# 19     4.536491e-07  2.603572e-09            1.461651e-08
# 20     1.674266e-05  1.445401e-05            1.705088e-05
# 21     1.036237e-04  5.867633e-06            5.530433e-07
# 22     2.880552e-08  4.034786e-06            6.263174e-09
# 23     4.380346e-04  4.016896e-05            2.612907e-06
# 24     9.678065e-08  4.815744e-08            2.988134e-05
# 25     1.464052e-08  1.049353e-08            1.233470e-08
# 26     2.173596e-06  1.519088e-08            3.584617e-08
# 27     1.014867e-03  1.916186e-03            9.347585e-07
# 28     1.583166e-06  3.116993e-07            2.606658e-05
# 29     8.663687e-05  4.229695e-05            1.844493e-05
# ...             ...           ...                     ...
# 10327  1.289546e-06  2.129726e-08            4.514679e-08
# 10328  4.028088e-06  2.564471e-08            2.689939e-07
# 10329  7.882271e-04  3.042014e-06            1.689175e-05
# 10330  4.075997e-06  3.264048e-05            2.896789e-06
# 10331  1.229159e-06  1.141086e-07            8.607644e-07
# 10332  9.192287e-06  2.708944e-06            1.632746e-05
# 10333  2.858126e-09  7.143303e-10            3.408903e-10
# 10334  1.390441e-05  1.488006e-06            1.277919e-04
# 10335  2.173380e-07  1.823612e-07            1.966830e-08
# 10336  3.238440e-05  2.309430e-05            1.846434e-05
# 10337  1.643772e-04  6.415837e-08            3.011291e-09
# 10338  6.081559e-07  1.467572e-06            6.055909e-07
# 10339  3.498143e-06  4.577776e-06            6.000280e-07
# 10340  3.144984e-07  1.673534e-06            1.498663e-06
# 10341  9.782161e-07  2.672277e-07            1.934731e-07
# 10342  1.002215e-06  9.327813e-07            1.059956e-02
# 10343  2.836610e-06  2.680979e-07            1.721569e-06
# 10344  1.234274e-05  7.209745e-06            1.791468e-05
# 10345  5.001739e-06  1.230047e-07            7.489371e-07
# 10346  1.777385e-07  3.007360e-07            7.723903e-07
# 10347  2.110370e-06  1.539176e-08            8.755794e-07
# 10348  3.454314e-07  3.170871e-06            1.243902e-06
# 10349  1.059049e-07  1.419281e-08            5.514707e-08
# 10350  3.579854e-04  1.146711e-06            1.809455e-04
# 10351  1.874001e-03  1.198158e-04            9.998813e-05
# 10352  1.805074e-05  1.143585e-06            1.709624e-06
# 10353  1.459432e-07  9.992452e-01            1.156874e-08
# 10354  7.563456e-06  2.860080e-08            5.303979e-06
# 10355  4.408238e-07  2.265491e-08            1.859427e-07
# 10356  2.788965e-06  1.996071e-07            9.762173e-08
#
#        west_highland_white_terrier       whippet  wire-haired_fox_terrier  \
# 0                     8.161407e-09  9.549304e-08             2.376628e-08
# 1                     6.131715e-06  1.298342e-07             7.373106e-09
# 2                     1.164154e-08  8.455832e-07             6.475479e-08
# 3                     6.978020e-07  8.456096e-06             4.466418e-08
# 4                     8.993936e-05  8.305112e-05             1.446322e-05
# 5                     6.168486e-06  5.187510e-06             2.016747e-04
# 6                     7.074903e-08  1.177175e-08             8.094646e-07
# 7                     3.653043e-04  2.177934e-06             1.205146e-06
# 8                     1.084471e-07  2.308173e-06             4.329720e-07
# 9                     7.543873e-09  1.584674e-09             3.784119e-08
# 10                    1.726292e-07  3.382616e-07             3.846426e-09
# 11                    7.427163e-05  1.127595e-05             6.657226e-03
# 12                    2.543699e-09  2.371620e-09             2.296488e-09
# 13                    2.684026e-04  3.331263e-06             1.225972e-04
# 14                    7.630712e-08  3.657164e-06             3.334036e-06
# 15                    5.234467e-08  2.639996e-07             3.281770e-08
# 16                    2.630266e-06  1.824205e-07             2.395816e-06
# 17                    2.716211e-04  4.879596e-04             2.271048e-02
# 18                    2.132889e-07  5.507146e-07             1.068551e-03
# 19                    1.173876e-09  7.068025e-06             4.811740e-09
# 20                    2.350142e-02  4.293652e-05             1.660595e-04
# 21                    3.600898e-06  3.341893e-05             3.229620e-06
# 22                    2.753974e-08  2.934675e-06             2.122436e-07
# 23                    8.603096e-06  8.485118e-05             1.926868e-06
# 24                    2.787015e-08  7.481341e-08             1.189090e-07
# 25                    5.277319e-08  8.384576e-09             1.545101e-09
# 26                    2.242730e-09  1.999634e-07             1.060351e-08
# 27                    3.867681e-07  1.313549e-02             8.776023e-06
# 28                    2.715178e-08  1.004344e-07             1.627011e-07
# 29                    5.579883e-06  1.548711e-04             3.369110e-02
# ...                            ...           ...                      ...
# 10327                 4.509204e-08  4.113138e-08             6.723793e-08
# 10328                 1.152720e-07  2.399743e-07             8.766342e-08
# 10329                 2.450059e-05  2.296646e-04             3.260133e-05
# 10330                 3.864361e-06  6.065184e-01             6.423919e-05
# 10331                 1.504882e-06  5.322227e-07             6.655379e-07
# 10332                 3.140277e-06  7.300995e-06             1.306397e-04
# 10333                 1.418231e-07  2.438176e-07             7.046698e-09
# 10334                 6.199909e-08  2.471382e-07             2.257714e-07
# 10335                 2.264119e-07  7.491174e-07             1.987436e-08
# 10336                 6.345540e-07  1.945248e-05             1.097994e-01
# 10337                 4.491398e-10  2.707710e-08             1.726796e-06
# 10338                 1.276264e-05  9.730843e-07             1.217345e-05
# 10339                 1.664370e-05  3.085866e-06             8.052058e-07
# 10340                 1.567859e-05  7.019415e-06             1.289745e-06
# 10341                 8.356078e-07  1.955853e-06             2.008838e-08
# 10342                 1.660719e-07  1.529145e-07             2.980780e-07
# 10343                 2.418171e-06  1.018447e-05             5.892071e-03
# 10344                 5.670401e-04  6.052386e-05             4.070584e-06
# 10345                 1.674584e-06  6.976123e-06             2.526662e-07
# 10346                 3.249807e-06  9.782284e-08             3.295231e-07
# 10347                 2.522330e-07  1.010561e-07             2.333285e-07
# 10348                 8.372751e-05  1.779833e-05             8.711282e-05
# 10349                 2.844937e-08  3.645330e-08             1.352200e-08
# 10350                 2.361432e-05  1.940564e-04             1.657427e-04
# 10351                 1.172706e-05  4.225816e-05             1.106475e-04
# 10352                 2.311705e-07  5.247450e-06             5.284396e-06
# 10353                 3.339592e-08  1.897514e-06             4.613618e-07
# 10354                 1.084514e-06  2.145270e-07             1.326559e-06
# 10355                 1.739394e-06  1.329841e-06             3.018630e-08
# 10356                 5.788698e-07  4.100845e-05             1.704938e-07
#
#        yorkshire_terrier
# 0           1.251092e-07
# 1           2.473148e-08
# 2           3.942433e-08
# 3           1.407552e-07
# 4           4.892287e-04
# 5           8.614146e-05
# 6           2.870009e-05
# 7           9.694315e-07
# 8           4.686183e-08
# 9           8.982182e-10
# 10          1.117144e-06
# 11          2.683987e-06
# 12          7.744128e-10
# 13          5.406126e-03
# 14          1.126451e-06
# 15          1.173820e-08
# 16          9.256871e-05
# 17          2.391589e-05
# 18          2.670824e-06
# 19          5.581928e-08
# 20          2.644530e-05
# 21          1.244669e-06
# 22          1.202129e-07
# 23          8.888752e-07
# 24          8.333580e-07
# 25          6.104080e-09
# 26          1.000421e-09
# 27          8.945930e-07
# 28          1.393835e-07
# 29          4.052935e-05
# ...                  ...
# 10327       1.281610e-07
# 10328       3.342435e-07
# 10329       2.065947e-05
# 10330       7.377525e-06
# 10331       4.438643e-03
# 10332       2.478788e-06
# 10333       1.498981e-08
# 10334       1.589501e-08
# 10335       1.598180e-09
# 10336       7.025951e-05
# 10337       3.221093e-09
# 10338       8.569864e-05
# 10339       4.130019e-06
# 10340       2.052577e-04
# 10341       8.040801e-08
# 10342       1.292588e-07
# 10343       5.755870e-06
# 10344       2.603553e-04
# 10345       8.387491e-07
# 10346       6.836351e-07
# 10347       1.936692e-07
# 10348       2.868748e-05
# 10349       1.830446e-09
# 10350       9.214858e-04
# 10351       1.653634e-04
# 10352       1.791395e-07
# 10353       1.324429e-08
# 10354       3.988059e-06
# 10355       8.758422e-06
# 10356       4.000342e-08
#
# [10357 rows x 121 columns]

# %% [markdown]
# **Loss is 0.26657**
#
# ---
#
# ![image](https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/rank_1.PNG)

# %% [markdown]
# # Play with this model

# %%
import mxnet as mx
from mxnet import autograd
from mxnet import gluon
from mxnet import image
from mxnet import init
from mxnet import nd
from mxnet.gluon.data import vision
from mxnet.gluon.model_zoo import vision as models
import numpy as np
from tqdm import tqdm

import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
ctx = mx.cpu() # use cpu   gpu will cause python stop working here

preprocessing = [
    image.ForceResizeAug((224,224)), # Make resize shorter edge to size augmenter.
    image.ColorNormalizeAug(mean=nd.array([0.485, 0.456, 0.406]), std=nd.array([0.229, 0.224, 0.225])) # Mean and std normalization
]

def transform(data, label):
    data = data.astype('float32') / 255  # transform type to float and do normalization
    for pre in preprocessing:
        data = pre(data) # preprocessing data
    
    data = nd.transpose(data, (2,0,1)) # Transpose image to N, H, W  Kaggle image is BGR but we need RGB here
    return data, nd.array([label]).asscalar().astype('float32') # return to ndARRARY

def get_features(net, data):
    features = []
    labels = []

    for X, y in tqdm(data): # tqdm to display the schedule
        feature = net.features(X.as_in_context(ctx)) # return target arrary of image features
        features.append(feature.asnumpy()) # asnumpy() -> convert to numpy array  superposition features
        labels.append(y.asnumpy()) # superposition labels
    
    features = np.concatenate(features, axis=0) # splice big data fast
    labels = np.concatenate(labels, axis=0)
    return features, labels

# %%
preprocessing[0] = image.ForceResizeAug((224,224))
imgs = vision.ImageFolderDataset('for_test', transform=transform)
data = gluon.data.DataLoader(imgs, 64)

#features_vgg, _ = get_features(models.vgg16_bn(pretrained=True, ctx=ctx), data)
features_resnet_test, _ = get_features(models.resnet152_v1(pretrained=True, ctx=ctx), data)
features_densenet_test, _ = get_features(models.densenet161(pretrained=True, ctx=ctx), data)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:07<00:00,  7.08s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:06<00:00,  6.08s/it]

# %%
preprocessing[0] = image.ForceResizeAug((299,299))
imgs_299 = vision.ImageFolderDataset('for_test', transform=transform)
data_299 = gluon.data.DataLoader(imgs_299, 64)

features_inception_test, _ = get_features(models.inception_v3(pretrained=True, ctx=ctx), data)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:04<00:00,  4.06s/it]

# %%
features_resnet_test = features_resnet_test.reshape(features_resnet_test.shape[:2])
features_inception_test = features_inception_test.reshape(features_inception_test.shape[:2])

features_test = np.concatenate([features_resnet_test, features_densenet_test, features_inception_test], axis=-1)

# %%
features_test.shape
# Out:
# (9L, 6304L)

# %%
# %%time
ctx = mx.gpu()
output = nd.softmax(net(nd.array(features_test).as_in_context(ctx))).asnumpy()
# Out:
# Wall time: 7 ms

# %%
df = pd.read_csv('play.csv')

for i, c in enumerate(df.columns[1:]):
    df[c] = output[:,i]
    
df
# Out:
#         id  affenpinscher  afghan_hound  african_hunting_dog      airedale  \
# 0    gakki       0.003300  2.146267e-03         2.374506e-02  4.693337e-03
# 1      lbj       0.010391  3.426854e-03         3.375243e-03  3.388047e-03
# 2  lbj_dog       0.002522  2.641871e-03         2.419023e-02  6.603371e-04
# 3  minghui       0.002394  1.505301e-03         2.959822e-03  1.297245e-03
# 4  shiyuan       0.001131  9.817295e-02         1.452859e-02  2.528736e-04
# 5      sjw       0.002359  2.539508e-03         3.031914e-03  2.468147e-04
# 6     wifi       0.000003  1.934447e-07         2.280943e-08  2.860270e-06
# 7   wifi_1       0.000001  8.924700e-08         7.369625e-09  2.967036e-07
# 8      zjm       0.001544  1.453925e-02         2.367935e-04  2.430328e-04
#
#    american_staffordshire_terrier   appenzeller  australian_terrier  \
# 0                    1.467181e-03  5.373989e-02        3.295791e-03
# 1                    1.024398e-02  2.715941e-02        1.742182e-03
# 2                    1.211232e-05  3.938686e-03        1.117741e-03
# 3                    1.244449e-03  2.990543e-02        2.967193e-02
# 4                    1.650364e-04  2.471526e-02        6.515169e-03
# 5                    1.971229e-03  2.586129e-02        1.602074e-03
# 6                    3.943605e-07  4.538414e-07        2.819758e-06
# 7                    1.479544e-08  4.251804e-08        9.052362e-07
# 8                    1.788755e-03  1.716408e-03        6.008908e-03
#
#         basenji        basset        ...          toy_poodle   toy_terrier  \
# 0  1.068859e-02  9.301095e-04        ...            0.027639  7.054830e-04
# 1  1.356574e-02  1.189596e-03        ...            0.010381  1.482023e-02
# 2  1.864619e-03  4.635472e-04        ...            0.001561  1.189174e-03
# 3  1.066965e-02  6.665795e-04        ...            0.000460  6.300951e-05
# 4  2.078568e-02  8.253477e-04        ...            0.048205  9.456469e-04
# 5  2.243339e-01  7.441605e-03        ...            0.007852  1.251200e-03
# 6  3.786133e-07  1.058913e-06        ...            0.007200  8.603908e-07
# 7  8.970682e-08  9.339616e-09        ...            0.000281  2.829024e-07
# 8  1.152762e-03  2.270173e-03        ...            0.002381  5.656866e-05
#
#          vizsla  walker_hound    weimaraner  welsh_springer_spaniel  \
# 0  4.325586e-03  4.445586e-02  4.072518e-04            1.535987e-03
# 1  1.788112e-03  5.032847e-04  1.256199e-02            7.862886e-03
# 2  2.393864e-04  1.622491e-02  1.833896e-04            1.213803e-02
# 3  3.236760e-03  1.686336e-02  1.086515e-03            3.462723e-04
# 4  9.945760e-04  2.322860e-03  7.821865e-05            3.896379e-03
# 5  7.197974e-04  1.414346e-02  6.925876e-05            7.288409e-03
# 6  3.960791e-07  6.462409e-07  9.855820e-07            6.743753e-07
# 7  2.562145e-07  5.826296e-08  5.146887e-08            2.088315e-08
# 8  2.209296e-02  6.531134e-02  2.054053e-04            8.650993e-05
#
#    west_highland_white_terrier       whippet  wire-haired_fox_terrier  \
# 0                     0.001510  8.106782e-02             7.456132e-04
# 1                     0.004149  2.245429e-02             7.563993e-04
# 2                     0.003025  1.089650e-03             2.595427e-04
# 3                     0.000417  1.717968e-02             2.195678e-02
# 4                     0.005804  1.843704e-03             7.732998e-04
# 5                     0.018366  8.551370e-03             5.842790e-03
# 6                     0.000056  1.048744e-06             2.104093e-07
# 7                     0.000002  3.687507e-07             6.574365e-08
# 8                     0.002278  2.512626e-01             2.411311e-03
#
#    yorkshire_terrier
# 0           0.075522
# 1           0.006772
# 2           0.022409
# 3           0.016392
# 4           0.057777
# 5           0.005577
# 6           0.000025
# 7           0.000006
# 8           0.019337
#
# [9 rows x 121 columns]

# %%
df1 = pd.read_csv('play_pred.csv')

# %%
wifi_1 = df[7:8]
del wifi_1['id']
wifi_1.max(axis=1)
# Out:
# 7    0.999366
# dtype: float32

# %% [markdown]
# 99.9366% **pomeranian**  in predicted csv file
#
# <img src="https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/wifi_1.jpg" width="400px" align="left"/>
# <img src="https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/pomeranian.jpg" width="400px" align="middle"/>

# %%
lbj_dog = df[2:3]
del lbj_dog['id']
lbj_dog.max(axis=1)
# Out:
# 2    0.181071
# dtype: float32

# %% [markdown]
# 0.181071 coresspoding **pembroke**  in predicted csv file
#
# <img src="https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/lbj_dog.jpg" width="300px" align="left"/>
# <img src="https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/pembroke.jpg" width="350px" align="middle"/>

# %%
gakki = df[0:1]
del gakki['id']
gakki.max(axis=1)
# Out:
# 0    0.081068
# dtype: float32

# %% [markdown]
# 0.081068 coresspoding **whippet** in predicted csv file
#
# <img src="https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/gakki.jpg" width="200px" align="left"/>
# <img src="https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/whippet.jpg" width="250px" align="middle"/>

# %%
lbj = df[1:2]
del lbj['id']
lbj.max(axis=1)
# Out:
# 1    0.070452
# dtype: float32

# %% [markdown]
# 0.070452 coresspoding **italian_greyhound**  in predicted csv file
#
# <img src="https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/lbj.jpg" width="200px" align="left"/>
# <img src="https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/italian_greyhound.jpg" width="300px" align="middle"/>

# %%
shiyuan = df[4:5]
del shiyuan['id']
shiyuan.max(axis=1)
# Out:
# 4    0.138123
# dtype: float32

# %% [markdown]
# 0.138123 coresspoding **japanese_spaniel**  in predicted csv file
#
# <img src="https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/shiyuan.jpg" width="400px" align="left"/>
# <img src="https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/japanese_spaniel.jpg" width="150px" align="middle"/>

# %%
sjw = df[5:6]
del sjw['id']
sjw.max(axis=1)
# Out:
# 5    0.224334
# dtype: float32

# %% [markdown]
#  0.224334 coresspoding **basenji**  in predicted csv file
#
# <img src="https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/sjw.jpg" width="400px" align="left"/>
# <img src="https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/basenji.jpg" width="400px" align="middle"/>

# %%
zjm = df[8:9]
del zjm['id']
zjm.max(axis=1)
# Out:
# 8    0.251263
# dtype: float32

# %% [markdown]
# 0.251263 coresspoding **whippet** in predicted csv file
#
# <img src="https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/zjm.jpg" width="220px" align="left"/>
# <img src="https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/whippet.jpg" width="250px" align="middle"/>

# %%
minghui = df[3:4]
del minghui['id']
minghui.max(axis=1)
# Out:
# 3    0.255215
# dtype: float32

# %% [markdown]
# 0.255215 coresspoding **eskimo_dog**  in predicted csv file
#
# <img src="https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/minghui.jpg" width="200px" align="left"/>
# <img src="https://raw.githubusercontent.com/Trouble404/Kaggle-Dog-breed-Identification/master/readme_pic_add/eskimo_dog.jpg" width="350px" align="middle"/>
